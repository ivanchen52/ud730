# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve
import time

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# # Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# # Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# # Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

# %% [markdown]
# # Generate batches

# %%
train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %% [markdown]
# # Functions for predictions

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# # Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
      saved_sample_output.assign(tf.zeros([1, num_nodes])),saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %% [markdown]
# <img src="2017-08-30_171508.png">
# http://colah.github.io/posts/2015-08-Understanding-LSTMs/
# $$\sigma$$

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print('Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.294313 learning rate: 10.000000
# Minibatch perplexity: 26.96
# ================================================================================
# evnlco dsltley nxndhnciepdwahluet  x rneuqtfshr jbse  de  ogpq  puxx rlofnjjziid
# es s  imhahvn xzngpleoqmyiayg tkgh owoaexawds  zwrqztvwqqzepnzt rniot lrh tl o d
# arqa gzyey d p  slo kautte mgeolioeadozvr cwssrnhdsqt igwy itehdaxb xj c rdoggek
# wboawanb  nltvicypi  k tuc  ntdjeics nyln   odifvwmxgta xyifevbay iaeczawkixrepf
# ssbva ehaeewa menmssxtljngtadyyl uvnspgirjmetlenilkjesursysafpuua xawpraweksrnn
# ================================================================================
# Validation set perplexity: 20.18
# Average loss at step 100: 2.592350 learning rate: 10.000000
# Minibatch perplexity: 11.19
# Validation set perplexity: 10.83
# Average loss at step 200: 2.247425 learning rate: 10.000000
# Minibatch perplexity: 8.52
# Validation set perplexity: 8.61
# Average loss at step 300: 2.096302 learning rate: 10.000000
# Minibatch perplexity: 7.41
# Validation set perplexity: 8.00
# Average loss at step 400: 1.994185 learning rate: 10.000000
# Minibatch perplexity: 7.47
# Validation set perplexity: 7.81
# Average loss at step 500: 1.937522 learning rate: 10.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 7.12
# Average loss at step 600: 1.908377 learning rate: 10.000000
# Minibatch perplexity: 6.21
# Validation set perplexity: 6.96
# Average loss at step 700: 1.860639 learning rate: 10.000000
# Minibatch perplexity: 6.62
# Validation set perplexity: 6.66
# Average loss at step 800: 1.820263 learning rate: 10.000000
# Minibatch perplexity: 6.02
# Validation set perplexity: 6.37
# Average loss at step 900: 1.829063 learning rate: 10.000000
# Minibatch perplexity: 7.18
# Validation set perplexity: 6.21
# Average loss at step 1000: 1.828944 learning rate: 10.000000
# Minibatch perplexity: 5.62
# ================================================================================
# quary the sume prowic of bilnation and tack poders of soliry as desighe sment we
# ce while hun butters erocems as ncone intervers trub incless defold into filis a
# tative be furan fict devalle the cerver will usonia snuctic leterpiries or sive
# nin havil contrace wele freeflunk devollet alpoins in the stind for d hins ver a
# kher seve affyce for boph hind orfutes in user grait eass ous the setio arso ing
# ================================================================================
# Validation set perplexity: 6.02
# Average loss at step 1100: 1.778277 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.81
# Average loss at step 1200: 1.755326 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 5.73
# Average loss at step 1300: 1.736442 learning rate: 10.000000
# Minibatch perplexity: 5.71
# Validation set perplexity: 5.53
# Average loss at step 1400: 1.749771 learning rate: 10.000000
# Minibatch perplexity: 5.97
# Validation set perplexity: 5.51
# Average loss at step 1500: 1.739897 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 5.37
# Average loss at step 1600: 1.746720 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 5.38
# Average loss at step 1700: 1.715784 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 5.42
# Average loss at step 1800: 1.678491 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 5.20
# Average loss at step 1900: 1.643582 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 5.25
# Average loss at step 2000: 1.697719 learning rate: 10.000000
# Minibatch perplexity: 5.75
# ================================================================================
# ally be nublist desps this the laname computen monn and disa all work k it deluy
# s or whiut indualing by two kounds wooks in cauncian mode making mutitia eight d
# usted phobachasts with noble comtumen arbuas a american leading mi landancist gr
# gorwed pet is indivationsornuial jepht pinssantabra one nine s six eecort sampla
# ring in merchinuants singteists solds been five refairs mperla to pode languis f
# ================================================================================
# Validation set perplexity: 5.23
# Average loss at step 2100: 1.687844 learning rate: 10.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.90
# Average loss at step 2200: 1.682662 learning rate: 10.000000
# Minibatch perplexity: 6.32
# Validation set perplexity: 5.09
# Average loss at step 2300: 1.639896 learning rate: 10.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.93
# Average loss at step 2400: 1.658821 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.91
# Average loss at step 2500: 1.683712 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.68
# Average loss at step 2600: 1.654221 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 4.75
# Average loss at step 2700: 1.664619 learning rate: 10.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.76
# Average loss at step 2800: 1.652833 learning rate: 10.000000
# Minibatch perplexity: 5.71
# Validation set perplexity: 4.69
# Average loss at step 2900: 1.649218 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 4.73
# Average loss at step 3000: 1.650316 learning rate: 10.000000
# Minibatch perplexity: 4.92
# ================================================================================
# ands eductbly saced he basneway dispial in a succeange germap villally thres whi
# s reformets heletoble of supon the zerons yawh the united in prictre expeans rac
# le gorcha hik he secerts and royackerism the hild on sometonitges capae suppent
# y deadem of green rapks of state eneducions liness sevaldandis der tecslucteify
# jear dixa do the propetice wary grat sazster beformer denntaull of zero suarn hi
# ================================================================================
# Validation set perplexity: 4.68
# Average loss at step 3100: 1.629414 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 4.71
# Average loss at step 3200: 1.648876 learning rate: 10.000000
# Minibatch perplexity: 5.61
# Validation set perplexity: 4.72
# Average loss at step 3300: 1.637172 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.62
# Average loss at step 3400: 1.666352 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.73
# Average loss at step 3500: 1.659500 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 4.70
# Average loss at step 3600: 1.669736 learning rate: 10.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.45
# Average loss at step 3700: 1.644406 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.54
# Average loss at step 3800: 1.644313 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.73
# Average loss at step 3900: 1.636904 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.58
# Average loss at step 4000: 1.650381 learning rate: 10.000000
# Minibatch perplexity: 4.66
# ================================================================================
# d the unders latine to ferestion of the jack hodesetmal and its lisilabe sphorti
# n zew br adortical s harracted the beholibate etchs behings is lighter stite byr
# ckes manys lightific attecped the vievent mapped production consires of viegt to
# vic of maerospach marrochised or usidilatent and freduit queck ducined been beca
# nuut and and of example retpander the b swhoyest of seven flecto nothuanslation
# ================================================================================
# Validation set perplexity: 4.67
# Average loss at step 4100: 1.630753 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.68
# Average loss at step 4200: 1.635834 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.52
# Average loss at step 4300: 1.612513 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.59
# Average loss at step 4400: 1.609105 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.42
# Average loss at step 4500: 1.616126 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.64
# Average loss at step 4600: 1.610973 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.59
# Average loss at step 4700: 1.620487 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.47
# Average loss at step 4800: 1.628320 learning rate: 10.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 4.52
# Average loss at step 4900: 1.629848 learning rate: 10.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 4.62
# Average loss at step 5000: 1.606196 learning rate: 1.000000
# Minibatch perplexity: 4.55
# ================================================================================
# ing one nine five for the somes and shotime the slangan benstroctive introves he
# madooge the nown prolinion tenl the sopely of the contropres tatmed polity his p
# y fucture by with brief for by mirjest bills of rounk and h sirtine three five z
# an re goinds two ed the explany one six eight nine two put this nhs e people kin
# m pluring some five four j ral but and at shirgers paisted one nine five of any
# ================================================================================
# Validation set perplexity: 4.58
# Average loss at step 5100: 1.601807 learning rate: 1.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.38
# Average loss at step 5200: 1.582127 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.34
# Average loss at step 5300: 1.578086 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.33
# Average loss at step 5400: 1.578411 learning rate: 1.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 4.31
# Average loss at step 5500: 1.564833 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.28
# Average loss at step 5600: 1.578426 learning rate: 1.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.28
# Average loss at step 5700: 1.569093 learning rate: 1.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 4.31
# Average loss at step 5800: 1.580148 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.28
# Average loss at step 5900: 1.573027 learning rate: 1.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.26
# Average loss at step 6000: 1.545134 learning rate: 1.000000
# Minibatch perplexity: 5.07
# ================================================================================
# bal english om to liaring of brizis for repledack side wight one zero zero on to
# dical dehing by inflation dimutal meave least the wan as new by asogies these pe
# wint mf cillations with had and one nine eight seven six zero thnectarincy educc
# colot inteber untround and mader that bewan written was a code and bit one nine
# ed betwore is l eagrom it form it is anticiols evert great inshight by the fion
# ================================================================================
# Validation set perplexity: 4.26
# Average loss at step 6100: 1.561677 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.23
# Average loss at step 6200: 1.530252 learning rate: 1.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.25
# Average loss at step 6300: 1.546826 learning rate: 1.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.22
# Average loss at step 6400: 1.537959 learning rate: 1.000000
# Minibatch perplexity: 4.45
# Validation set perplexity: 4.23
# Average loss at step 6500: 1.554441 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.20
# Average loss at step 6600: 1.592986 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.21
# Average loss at step 6700: 1.577813 learning rate: 1.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.23
# Average loss at step 6800: 1.597839 learning rate: 1.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.22
# Average loss at step 6900: 1.583328 learning rate: 1.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.23
# Average loss at step 7000: 1.573668 learning rate: 1.000000
# Minibatch perplexity: 5.12
# ================================================================================
# rate militian miscom yout haves four given poes and the somebing dind mansute pe
#  ludails the whitin abmeniosman fections frencal inskired and between orisiol ca
# y aldrous a paines occur encoode septonett of the way but a eugromion is for inv
# bima ut the claimative arcoiod indivals mucry one six one zero the tay openers m
# haids house a is sonw the yearfing accuiated to rlyomails to chromabs is d and a
# ================================================================================
# Validation set perplexity: 4.19

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64
# github kcbighuge
graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
    
  # combined f,i,c,o
  fico_x = tf.Variable(tf.truncated_normal([4, vocabulary_size, num_nodes], -0.1, 0.1))
  #print(fico_x.get_shape().as_list())
  fico_m = tf.Variable(tf.truncated_normal([4, num_nodes, num_nodes], -0.1, 0.1))
  fico_b = tf.Variable(tf.zeros([4, 1, num_nodes]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    
    i_list = tf.stack([i, i, i, i])
    #print('i_list',i_list.get_shape().as_list())
    o_list = tf.stack([o, o, o, o])
    ins = tf.matmul(i_list, fico_x)
    outs = tf.matmul(o_list, fico_m)
    h_x = ins + outs + fico_b
    #print('h_x',h_x.get_shape().as_list())
    
    #input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    #forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    #update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    #state = forget_gate * state + input_gate * tf.tanh(update)
    #output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)

    input_gate = tf.sigmoid(h_x[1,:,:])
    forget_gate = tf.sigmoid(h_x[0,:,:])
    update = tf.tanh(h_x[2,:,:])
    state = forget_gate*state + input_gate*update
    output_gate = tf.sigmoid(h_x[3,:,:])
    h = output_gate * tf.tanh(state)
    #print('h', h.get_shape().as_list())
    return h, state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
      saved_sample_output.assign(tf.zeros([1, num_nodes])),saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100
t0 = time.time()
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print('Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(valid_logprob / valid_size)))

m, s = divmod(time.time()-t0, 60)
h, m = divmod(m, 60)
print("%d:%02d:%02d" % (h, m, s), 'elapsed time')
# Out:
# Initialized
# Average loss at step 0: 3.297116 learning rate: 10.000000
# Minibatch perplexity: 27.03
# ================================================================================
# wctyiozebh tkj   vrrxjfp bimzj be nozjoitneqcips ktdirsrvek  zwuq qmg l gebjeanm
# yoewsp  pisrdj enxsosntear t  zofep ybbisbcmare etv wc qtlpowavx ni acgnbogr sjf
# rrolalmft vdderbqa oiwsvevjarxrgtifa lwwixgdnvamnnyivzzeinyuewdaeoznpueqfeeei p
# re uneqouvcqkecmhn muhisxcomidftotqrks fukof kgsh jeh ncgtepocpcz  catdsa ncjiet
# ubli cojktrihkueootilztco otepdizulrostqbbaj thdpjlyoeoftseoudoenk nnhsloj tftao
# ================================================================================
# Validation set perplexity: 20.17
# Average loss at step 100: 2.588240 learning rate: 10.000000
# Minibatch perplexity: 10.08
# Validation set perplexity: 10.59
# Average loss at step 200: 2.262508 learning rate: 10.000000
# Minibatch perplexity: 8.34
# Validation set perplexity: 8.92
# Average loss at step 300: 2.105784 learning rate: 10.000000
# Minibatch perplexity: 7.49
# Validation set perplexity: 8.19
# Average loss at step 400: 2.023265 learning rate: 10.000000
# Minibatch perplexity: 7.91
# Validation set perplexity: 7.32
# Average loss at step 500: 1.937632 learning rate: 10.000000
# Minibatch perplexity: 7.37
# Validation set perplexity: 7.04
# Average loss at step 600: 1.906747 learning rate: 10.000000
# Minibatch perplexity: 7.06
# Validation set perplexity: 6.79
# Average loss at step 700: 1.876625 learning rate: 10.000000
# Minibatch perplexity: 7.06
# Validation set perplexity: 6.43
# Average loss at step 800: 1.849905 learning rate: 10.000000
# Minibatch perplexity: 6.00
# Validation set perplexity: 6.32
# Average loss at step 900: 1.829844 learning rate: 10.000000
# Minibatch perplexity: 6.00
# Validation set perplexity: 6.18
# Average loss at step 1000: 1.785950 learning rate: 10.000000
# Minibatch perplexity: 5.32
# ================================================================================
# wer by the viciand in the of the but kus the as kites ims vilw woriting not pabi
# peryed brimialy at stent eight the was who expersic speeed four ech goal leep an
# litated of historist by stass for the orign to eight was suspon seven the of the
# wates celversion new his it wapola no its to engun merfam bybom  s savins ponems
# nad is at seten sungs mange withmat and of the qmspupindinstaris ogno optariencs
# ================================================================================
# Validation set perplexity: 6.08
# Average loss at step 1100: 1.784745 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 5.73
# Average loss at step 1200: 1.773110 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 5.46
# Average loss at step 1300: 1.762874 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 5.58
# Average loss at step 1400: 1.732997 learning rate: 10.000000
# Minibatch perplexity: 5.99
# Validation set perplexity: 5.41
# Average loss at step 1500: 1.721723 learning rate: 10.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 5.37
# Average loss at step 1600: 1.702899 learning rate: 10.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 5.23
# Average loss at step 1700: 1.694446 learning rate: 10.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 5.19
# Average loss at step 1800: 1.709809 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 4.88
# Average loss at step 1900: 1.691917 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.85
# Average loss at step 2000: 1.695258 learning rate: 10.000000
# Minibatch perplexity: 6.29
# ================================================================================
# lex other the set enit and to than aport scevory croginal that philents onter su
# t tambrinkpled i was s mylte damen pp the clayer the at excounty ajone with exta
# joar in lost ety sirce into a perportib formy to the s forth a laxaed carculatur
# dia fefelodish deades diefes canergy of can him a caulennee ond chund ythap are
# elten arriby necalida normation two damesp that this commonet euchedia literatus
# ================================================================================
# Validation set perplexity: 4.82
# Average loss at step 2100: 1.682983 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.80
# Average loss at step 2200: 1.690366 learning rate: 10.000000
# Minibatch perplexity: 6.57
# Validation set perplexity: 4.88
# Average loss at step 2300: 1.678805 learning rate: 10.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.76
# Average loss at step 2400: 1.666914 learning rate: 10.000000
# Minibatch perplexity: 5.63
# Validation set perplexity: 4.68
# Average loss at step 2500: 1.674474 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.47
# Average loss at step 2600: 1.663968 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.79
# Average loss at step 2700: 1.650413 learning rate: 10.000000
# Minibatch perplexity: 5.90
# Validation set perplexity: 4.66
# Average loss at step 2800: 1.643682 learning rate: 10.000000
# Minibatch perplexity: 5.61
# Validation set perplexity: 4.77
# Average loss at step 2900: 1.637444 learning rate: 10.000000
# Minibatch perplexity: 5.46
# Validation set perplexity: 4.68
# Average loss at step 3000: 1.661493 learning rate: 10.000000
# Minibatch perplexity: 5.94
# ================================================================================
# y blowns allif film of bearies requestional monopolic poundard best strested by
# maly dobose is three seate seven populerate wak torkion losiuge sie the secrabat
# wsils movepesial used or is valuafily collices afsears pound technmloty keneer i
# licerters are now a pogestowo reachablarr or treasing the spectition calcor defi
#  heir the percorvot a is quoditically avari states program as hell yewrations of
# ================================================================================
# Validation set perplexity: 4.72
# Average loss at step 3100: 1.631022 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 4.71
# Average loss at step 3200: 1.640526 learning rate: 10.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 4.60
# Average loss at step 3300: 1.635043 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.64
# Average loss at step 3400: 1.623200 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.71
# Average loss at step 3500: 1.609805 learning rate: 10.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.69
# Average loss at step 3600: 1.628381 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.56
# Average loss at step 3700: 1.602016 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.58
# Average loss at step 3800: 1.595905 learning rate: 10.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 4.58
# Average loss at step 3900: 1.584792 learning rate: 10.000000
# Minibatch perplexity: 6.07
# Validation set perplexity: 4.61
# Average loss at step 4000: 1.614408 learning rate: 10.000000
# Minibatch perplexity: 4.57
# ================================================================================
# py that perzently conficityr offible and the new yeuxted ovgiledre note valles s
# ed king the bust governe understrians babil s soot beten southear one nine zero
# tis it one oftentt maching jusk bean brite as a manang king aragan receidents tu
# qual form some a bool oux granta seiging reserve mateh one of biolons propatingy
# ther and leat one five of the neven with lather in tridation massenes pailly int
# ================================================================================
# Validation set perplexity: 4.58
# Average loss at step 4100: 1.622107 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 4.66
# Average loss at step 4200: 1.606462 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.48
# Average loss at step 4300: 1.567378 learning rate: 10.000000
# Minibatch perplexity: 5.75
# Validation set perplexity: 4.51
# Average loss at step 4400: 1.593097 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.45
# Average loss at step 4500: 1.580342 learning rate: 10.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.43
# Average loss at step 4600: 1.579159 learning rate: 10.000000
# Minibatch perplexity: 4.58
# Validation set perplexity: 4.37
# Average loss at step 4700: 1.592817 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.37
# Average loss at step 4800: 1.587097 learning rate: 10.000000
# Minibatch perplexity: 4.43
# Validation set perplexity: 4.43
# Average loss at step 4900: 1.607919 learning rate: 10.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 4.50
# Average loss at step 5000: 1.616560 learning rate: 1.000000
# Minibatch perplexity: 4.71
# ================================================================================
# xaple bunt of avoilation isllian and frees prana serites to simjurch religanoy a
# they populasing ribersthyrica s the phitulest at the brieked by andeased reto it
# joak eothern thunetond statervyby iten macifant interent as speach its throbg or
# xandarists the nation one nine four three cerpandromy self they rone worlder one
# ly offelised second in prositey and neal well the philare discorency as amberge
# ================================================================================
# Validation set perplexity: 4.47
# Average loss at step 5100: 1.575040 learning rate: 1.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 4.29
# Average loss at step 5200: 1.586177 learning rate: 1.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.20
# Average loss at step 5300: 1.568370 learning rate: 1.000000
# Minibatch perplexity: 4.54
# Validation set perplexity: 4.21
# Average loss at step 5400: 1.556476 learning rate: 1.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.19
# Average loss at step 5500: 1.550791 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 4.14
# Average loss at step 5600: 1.543542 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.13
# Average loss at step 5700: 1.574708 learning rate: 1.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.13
# Average loss at step 5800: 1.567011 learning rate: 1.000000
# Minibatch perplexity: 4.34
# Validation set perplexity: 4.12
# Average loss at step 5900: 1.574117 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.18
# Average loss at step 6000: 1.538352 learning rate: 1.000000
# Minibatch perplexity: 4.57
# ================================================================================
# age or leadmen one sie zero the nures armant pubes that time is the nortwer orde
# lessly at artim hears authorwors of saffana bookey  lemage rocance play induswor
# or s naty to frimap which was times into six ie the mone can bat on aills betwee
# on book been calte groy then we time image s enely s saso com how found and ladj
# joun hader trikages arage few bugnin influence jub uld syigno to renvente somini
# ================================================================================
# Validation set perplexity: 4.15
# Average loss at step 6100: 1.582226 learning rate: 1.000000
# Minibatch perplexity: 4.25
# Validation set perplexity: 4.16
# Average loss at step 6200: 1.583578 learning rate: 1.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 4.16
# Average loss at step 6300: 1.572268 learning rate: 1.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.17
# Average loss at step 6400: 1.586715 learning rate: 1.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 4.20
# Average loss at step 6500: 1.592476 learning rate: 1.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.18
# Average loss at step 6600: 1.571697 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.19
# Average loss at step 6700: 1.570167 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.20
# Average loss at step 6800: 1.576534 learning rate: 1.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.20
# Average loss at step 6900: 1.610630 learning rate: 1.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.21
# Average loss at step 7000: 1.594956 learning rate: 1.000000
# Minibatch perplexity: 4.90
# ================================================================================
# gio havold a shouidral liaation city but such at numernematies this ward persani
# jenom also witkence read of hodaw emplead in entering root processboundembalfamo
# jer influed of the rain use of mitt of many the mus surviphimes others is cano w
# y system tige creation provent was regived relight suring starrist at the nou s
# ide one nine nine one but nine moundist is dope them pest forcial d in which pea
# ================================================================================
# Validation set perplexity: 4.19
# 2.2136213382085166 minutes elapsed
# 0:02:12

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
