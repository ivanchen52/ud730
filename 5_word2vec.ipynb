# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.911246
# Nearest to on: perimeter, ochre, inns, dnia, cyclist, inflows, fleischer, pointing,
# Nearest to were: dice, pikes, rocker, tempest, replacing, cretian, report, auk,
# Nearest to world: chimera, nssdc, quarterly, hoffmann, syllables, cavan, reina, conditioners,
# Nearest to during: taking, loot, obtainable, neighbors, purportedly, renouncing, gobind, daredevil,
# Nearest to see: sleep, cecilia, ssel, boldness, devry, passions, atzeret, disadvantageous,
# Nearest to eight: eternity, halted, dreamer, auric, loire, staves, lauderdale, connick,
# Nearest to one: heavenly, laborious, vu, migs, barks, habitable, amputees, literary,
# Nearest to can: profitable, geeks, fountains, helaman, astral, popper, alfv, nyu,
# Nearest to all: rutles, czar, pertwee, chisinau, terrific, synonym, hostile, authentication,
# Nearest to would: junichiro, kibo, chromatic, netbios, memories, windows, wimsey, jaina,
# Nearest to over: tutsis, submissions, levin, comptroller, purposely, prostrate, nursery, cuzco,
# Nearest to five: glucocorticoids, urbana, oppressors, burdens, rosters, settings, advert, aruba,
# Nearest to have: antidepressant, corbusier, tamil, regolith, flagship, seminars, excellence, tunneling,
# Nearest to zero: downed, incessantly, timestamp, erythromycin, grindcore, tolerances, euphoria, minster,
# Nearest to also: hogarth, webpages, racial, predictability, tutorials, relaxation, machete, tora,
# Nearest to four: anoint, vests, espagnole, rard, scanners, spooner, plasma, spends,
# Average loss at step 2000: 4.375398
# Average loss at step 4000: 3.868537
# Average loss at step 6000: 3.789196
# Average loss at step 8000: 3.690565
# Average loss at step 10000: 3.612740
# Nearest to on: warmly, in, ochre, during, at, germinate, cannes, howland,
# Nearest to were: are, was, have, prod, shasta, became, foote, gunner,
# Nearest to world: chimera, nell, clairvaux, vlaanderen, sushi, osz, interior, prosecutor,
# Nearest to during: renouncing, on, purportedly, in, batll, loot, cpus, neighbors,
# Nearest to see: francium, astrologers, sleep, devry, barbados, inhuman, bennington, sc,
# Nearest to eight: six, nine, four, five, three, seven, zero, two,
# Nearest to one: two, three, four, eight, six, seven, transvestite, foot,
# Nearest to can: would, may, profitable, should, fountains, were, helaman, widehat,
# Nearest to all: chisinau, usury, manipulating, yielding, conjure, org, pertwee, outpost,
# Nearest to would: can, should, may, to, will, fond, norton, illegitimacy,
# Nearest to over: levin, volunteer, comptroller, regards, spears, comm, latin, horowitz,
# Nearest to five: four, eight, six, three, seven, nine, zero, two,
# Nearest to have: had, be, has, malan, are, were, gunner, sleeps,
# Nearest to zero: five, eight, nine, six, three, seven, four, two,
# Nearest to also: often, which, there, who, it, not, alluvial, emerson,
# Nearest to four: eight, three, five, six, seven, two, nine, zero,
# Average loss at step 12000: 3.607573
# Average loss at step 14000: 3.571508
# Average loss at step 16000: 3.410443
# Average loss at step 18000: 3.459310
# Average loss at step 20000: 3.544477
# Nearest to on: in, warmly, upon, at, inflows, vivant, for, from,
# Nearest to were: are, was, had, be, have, been, by, became,
# Nearest to world: chimera, histories, interior, sushi, osz, quarterly, vlaanderen, clairvaux,
# Nearest to during: at, in, renouncing, purportedly, loot, after, taking, parlour,
# Nearest to see: francium, harmonizing, disadvantageous, pyre, dm, astrologers, barbados, georg,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to one: three, four, two, seven, six, five, eight, nine,
# Nearest to can: would, may, should, must, will, could, to, demonstrating,
# Nearest to all: yielding, these, chisinau, manipulating, several, many, some, org,
# Nearest to would: can, may, will, should, could, might, to, must,
# Nearest to over: volunteer, levin, regards, spears, horowitz, comm, previous, cochran,
# Nearest to five: six, eight, four, zero, seven, three, two, nine,
# Nearest to have: had, has, be, were, are, gunner, recognize, take,
# Nearest to zero: five, six, seven, four, eight, three, nine, two,
# Nearest to also: which, often, not, sometimes, who, never, now, alluvial,
# Nearest to four: six, seven, eight, three, five, two, nine, zero,
# Average loss at step 22000: 3.503175
# Average loss at step 24000: 3.491834
# Average loss at step 26000: 3.480093
# Average loss at step 28000: 3.483835
# Average loss at step 30000: 3.504020
# Nearest to on: upon, in, warmly, vivant, from, outside, during, about,
# Nearest to were: are, was, have, had, been, be, those, is,
# Nearest to world: chimera, histories, interior, braces, quarterly, stilgar, vlaanderen, osz,
# Nearest to during: after, in, when, at, renouncing, loot, within, since,
# Nearest to see: francium, mirrored, dm, harmonizing, cardinality, pyre, tidings, madly,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to one: two, four, seven, eight, three, five, six, nine,
# Nearest to can: may, would, could, should, will, must, cannot, might,
# Nearest to all: some, many, these, yielding, several, dissimilar, manipulating, impressionist,
# Nearest to would: can, may, could, will, should, might, to, must,
# Nearest to over: volunteer, levin, rube, canadiens, sanderson, nursery, slides, cochran,
# Nearest to five: four, eight, seven, six, three, nine, zero, two,
# Nearest to have: had, has, are, were, be, recognize, gunner, having,
# Nearest to zero: five, eight, four, seven, three, nine, six, two,
# Nearest to also: sometimes, often, now, never, it, which, there, who,
# Nearest to four: five, three, eight, six, seven, two, nine, zero,
# Average loss at step 32000: 3.504081
# Average loss at step 34000: 3.492749
# Average loss at step 36000: 3.454007
# Average loss at step 38000: 3.302918
# Average loss at step 40000: 3.431339
# Nearest to on: upon, at, during, in, about, warmly, lysergic, willed,
# Nearest to were: are, was, have, had, those, be, while, been,
# Nearest to world: chimera, histories, osz, metcalfe, interior, quarterly, vlaanderen, intrusion,
# Nearest to during: after, when, at, on, within, since, in, through,
# Nearest to see: francium, mirrored, list, dm, mountaineers, include, musics, can,
# Nearest to eight: nine, six, seven, five, four, zero, three, one,
# Nearest to one: seven, two, eight, six, four, five, nine, machiavelli,
# Nearest to can: may, would, will, could, should, must, cannot, might,
# Nearest to all: many, yielding, several, these, impressionist, any, dissimilar, synchronous,
# Nearest to would: will, could, can, may, should, might, must, did,
# Nearest to over: volunteer, levin, rube, apollo, into, preyed, antipope, spears,
# Nearest to five: seven, six, four, eight, three, zero, nine, two,
# Nearest to have: had, has, were, be, are, having, recognize, gunner,
# Nearest to zero: seven, five, nine, eight, six, three, four, two,
# Nearest to also: which, often, sometimes, now, never, usually, generally, there,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Average loss at step 42000: 3.436392
# Average loss at step 44000: 3.453332
# Average loss at step 46000: 3.449263
# Average loss at step 48000: 3.350293
# Average loss at step 50000: 3.386358
# Nearest to on: upon, warmly, in, at, episcopate, viking, under, for,
# Nearest to were: are, was, have, had, be, been, supranationalism, those,
# Nearest to world: chimera, metcalfe, histories, marys, osz, marathas, interior, stilgar,
# Nearest to during: after, when, within, in, at, since, through, against,
# Nearest to see: francium, references, but, include, dm, mirrored, reese, astrologers,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to one: two, four, six, seven, eight, three, five, nine,
# Nearest to can: may, would, could, will, should, must, might, cannot,
# Nearest to all: yielding, both, many, these, impressionist, some, fao, knicks,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to over: volunteer, levin, into, around, magnetosphere, futurism, chalker, rube,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to have: had, has, were, be, are, recognize, having, zubaydah,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to also: often, which, sometimes, now, never, actually, usually, then,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Average loss at step 52000: 3.438601
# Average loss at step 54000: 3.427230
# Average loss at step 56000: 3.442331
# Average loss at step 58000: 3.402297
# Average loss at step 60000: 3.394797
# Nearest to on: upon, through, in, under, within, sukarnoputri, sulfides, dram,
# Nearest to were: are, was, had, have, supranationalism, those, including, although,
# Nearest to world: metcalfe, histories, chimera, interior, marys, quarterly, civil, stilgar,
# Nearest to during: after, within, before, when, in, following, since, despite,
# Nearest to see: include, dm, francium, list, but, can, references, stimulated,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to one: seven, two, four, five, six, eight, three, nine,
# Nearest to can: may, would, could, will, must, should, might, cannot,
# Nearest to all: many, some, these, any, yielding, those, both, several,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to over: around, renouncing, into, through, volunteer, hyenas, nan, levin,
# Nearest to five: four, six, seven, three, eight, nine, zero, two,
# Nearest to have: had, has, are, were, having, be, zubaydah, produce,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to also: now, often, sometimes, still, generally, usually, actually, which,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Average loss at step 62000: 3.244359
# Average loss at step 64000: 3.250927
# Average loss at step 66000: 3.400960
# Average loss at step 68000: 3.391948
# Average loss at step 70000: 3.357008
# Nearest to on: upon, in, through, warmly, within, sulfides, about, bark,
# Nearest to were: are, was, had, have, be, those, montreux, been,
# Nearest to world: histories, metcalfe, interior, stilgar, athena, sliced, chimera, quarterly,
# Nearest to during: after, before, within, in, when, despite, following, since,
# Nearest to see: list, include, reese, called, but, shepard, francium, rupiah,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to one: two, seven, four, six, five, eight, three, nine,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to all: some, many, any, both, various, several, these, yielding,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to over: around, about, renouncing, volunteer, through, hyenas, antipope, nan,
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to have: had, has, are, were, be, having, contain, include,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to also: still, often, now, which, sometimes, never, actually, generally,
# Nearest to four: five, seven, six, three, eight, two, zero, nine,
# Average loss at step 72000: 3.375239
# Average loss at step 74000: 3.349669
# Average loss at step 76000: 3.316712
# Average loss at step 78000: 3.350331
# Average loss at step 80000: 3.378642
# Nearest to on: upon, in, through, warmly, within, malone, hawick, episcopate,
# Nearest to were: are, was, had, have, be, supranationalism, been, became,
# Nearest to world: histories, metcalfe, interior, athena, chimera, marathas, restarted, nation,
# Nearest to during: after, when, in, before, within, throughout, despite, following,
# Nearest to see: list, include, according, but, dm, includes, francium, reese,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to one: seven, two, six, three, five, eight, four, nine,
# Nearest to can: could, will, may, would, must, should, cannot, might,
# Nearest to all: both, several, every, any, some, each, many, these,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to over: around, across, through, into, about, volunteer, renouncing, futurism,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to have: had, has, are, were, be, having, contain, include,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to also: often, now, still, sometimes, actually, which, gracefully, generally,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Average loss at step 82000: 3.410152
# Average loss at step 84000: 3.409179
# Average loss at step 86000: 3.389089
# Average loss at step 88000: 3.352890
# Average loss at step 90000: 3.362516
# Nearest to on: upon, warmly, under, onto, within, through, howland, at,
# Nearest to were: are, had, was, have, although, while, those, these,
# Nearest to world: histories, interior, nation, renewable, marathas, metcalfe, prosecutor, comet,
# Nearest to during: after, in, before, within, when, despite, throughout, until,
# Nearest to see: list, includes, include, according, theatrical, reese, rupiah, precaution,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to one: seven, two, four, eight, six, five, three, nine,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to all: several, both, some, every, yielding, any, many, these,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to over: around, through, across, futurism, into, volunteer, hyenas, about,
# Nearest to five: seven, eight, four, three, six, nine, zero, two,
# Nearest to have: had, has, were, are, be, contain, having, hyatt,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to also: often, still, which, now, sometimes, actually, generally, never,
# Nearest to four: seven, five, eight, six, three, nine, two, zero,
# Average loss at step 92000: 3.401709
# Average loss at step 94000: 3.249842
# Average loss at step 96000: 3.355203
# Average loss at step 98000: 3.244630
# Average loss at step 100000: 3.359167
# Nearest to on: upon, within, in, at, warmly, through, flagellate, onto,
# Nearest to were: are, was, have, these, had, although, those, supranationalism,
# Nearest to world: histories, interior, marathas, nation, metcalfe, prosecutor, athena, country,
# Nearest to during: after, in, despite, throughout, before, when, within, following,
# Nearest to see: includes, list, include, endeavours, references, according, reese, theatrical,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to one: two, four, seven, five, eight, six, three, nine,
# Nearest to can: may, could, will, should, cannot, would, must, might,
# Nearest to all: several, some, every, any, various, these, both, many,
# Nearest to would: will, could, may, might, can, should, must, cannot,
# Nearest to over: around, across, volunteer, futurism, euroscepticism, through, imperfectly, apollo,
# Nearest to five: seven, four, six, eight, three, zero, nine, two,
# Nearest to have: had, has, are, having, contain, be, were, include,
# Nearest to zero: five, seven, four, eight, six, nine, three, million,
# Nearest to also: actually, often, now, still, never, sometimes, which, generally,
# Nearest to four: six, seven, five, eight, three, two, nine, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in range(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  278.964233398
# Nearest to nine: engels, fated, dvd, hangzhou, brewery, amon, octagon, peebles,
# Nearest to was: obituaries, probes, sardis, lambasted, mercedes, insecure, foolish, catalyzed,
# Nearest to UNK: stretch, proconsul, meridian, monopolies, cadiz, reconnaissance, carotenoids, tribal,
# Nearest to used: netherlands, reinventing, foresight, banners, rif, undercover, contract, extremist,
# Nearest to s: averaging, submit, injurious, diagnostic, chakras, shooter, whirlwind, religious,
# Nearest to more: discos, highlands, morr, dever, intimidated, tease, svc, speer,
# Nearest to has: paasikivi, knute, patrolling, bleue, imitated, shifts, bauer, jets,
# Nearest to may: stratton, saxo, slope, patrilineal, andronicus, ancestors, gatling, died,
# Nearest to will: coder, chechens, occasionally, nitrile, explodes, thanked, fidonet, nutmeg,
# Nearest to use: lives, termination, kun, nationalists, misinterpretation, riddler, tolbert, reagents,
# Nearest to known: jiang, barsoom, sweeping, carlist, mah, diskette, represent, enamoured,
# Nearest to there: roll, tempus, ticket, aggregated, hank, mikvah, moderates, choices,
# Nearest to they: straight, plexus, censored, uprising, ou, pounds, modulus, liberal,
# Nearest to new: cutting, pennsylvania, tli, tropic, bryozoa, ulaanbaatar, depends, signified,
# Nearest to were: imt, range, nullification, vladivostok, mich, unaccented, sutcliffe, bruxelles,
# Nearest to two: annulment, buchner, dame, movements, catalog, typeset, slid, ret,
# Average loss at step  2000 :  114.095927398
# Average loss at step  4000 :  52.9278278301
# Average loss at step  6000 :  33.2918772087
# Average loss at step  8000 :  23.5707019503
# Average loss at step  10000 :  17.1129137932
# Nearest to nine: eight, zero, sisters, six, banjo, seven, five, flies,
# Nearest to was: is, flies, has, had, in, by, regions, when,
# Nearest to UNK: sisters, hymen, fc, the, toei, and, a, homomorphism,
# Nearest to used: netherlands, imdb, base, diagrams, fleet, contract, banners, scenes,
# Nearest to s: and, the, zero, hymen, UNK, h, his, religious,
# Nearest to more: seriousness, highlands, dns, discos, neoclassical, professors, sisters, netbios,
# Nearest to has: is, was, application, gypsy, dione, diagrams, representationalism, patrolling,
# Nearest to may: dass, died, divided, saxo, congregations, adopted, terminator, bhaskara,
# Nearest to will: theater, occasionally, introduced, daoud, green, chechens, toei, consulting,
# Nearest to use: termination, lives, sisters, democracy, ip, homicide, fraction, circumference,
# Nearest to known: sisters, begins, appear, response, sweeping, hay, el, archie,
# Nearest to there: choices, roll, ticket, hank, dylan, buried, critical, winners,
# Nearest to they: liberal, straight, pounds, ou, not, uprising, it, accelerated,
# Nearest to new: cutting, pennsylvania, depends, pathway, symplectic, critical, dark, accounting,
# Nearest to were: are, np, as, is, compact, across, crisis, diagrams,
# Nearest to two: one, sisters, congregations, circumference, nine, in, olympian, flies,
# Average loss at step  12000 :  13.6615664773
# Average loss at step  14000 :  11.7017281179
# Average loss at step  16000 :  10.2473382624
# Average loss at step  18000 :  8.72515527821
# Average loss at step  20000 :  8.01135225928
# Nearest to nine: eight, zero, seven, six, five, widehat, four, sisters,
# Nearest to was: is, by, has, had, were, flies, when, in,
# Nearest to UNK: sisters, smells, hymen, widehat, fc, and, toei, referendums,
# Nearest to used: llc, erg, netherlands, imdb, tonal, diagrams, base, fleet,
# Nearest to s: and, zero, his, of, hymen, whirlwind, widehat, nine,
# Nearest to more: crowned, excalibur, highlands, electors, seriousness, oxidant, neoclassical, dns,
# Nearest to has: is, was, had, have, application, gypsy, dione, horton,
# Nearest to may: would, slope, could, dass, gw, saxo, divided, died,
# Nearest to will: widehat, chechens, would, occasionally, theater, introduced, to, disappearing,
# Nearest to use: termination, lives, misinterpretation, nationalists, sisters, fraction, coast, christianity,
# Nearest to known: sisters, hay, appear, consulted, begins, sweeping, a, response,
# Nearest to there: choices, it, roll, moderates, buried, ticket, they, which,
# Nearest to they: not, it, liberal, he, censored, there, pounds, widehat,
# Nearest to new: cutting, of, depends, and, pennsylvania, symplectic, parl, pathway,
# Nearest to were: are, was, is, and, by, compact, would, tarsus,
# Nearest to two: one, three, eight, zero, five, nine, sisters, four,
# Average loss at step  22000 :  7.36430683696
# Average loss at step  24000 :  6.8370025363
# Average loss at step  26000 :  6.40062092769
# Average loss at step  28000 :  6.25901777947
# Average loss at step  30000 :  6.21428877366
# Nearest to nine: eight, seven, five, zero, six, four, widehat, neutronic,
# Nearest to was: is, by, has, were, had, hemionus, lyman, in,
# Nearest to UNK: sisters, neutronic, smells, quagga, palatalization, hymen, toei, fc,
# Nearest to used: llc, erg, kiang, imdb, netherlands, tonal, diagrams, bfbs,
# Nearest to s: and, his, malagasy, hymen, zero, the, kiang, widehat,
# Nearest to more: crowned, electors, excalibur, oxidant, highlands, judea, wff, noble,
# Nearest to has: is, was, had, have, in, paasikivi, widehat, horton,
# Nearest to may: would, can, could, saxo, slope, will, prost, gw,
# Nearest to will: would, can, widehat, may, to, chechens, theater, sokal,
# Nearest to use: bytecode, termination, misinterpretation, lives, amount, nationalists, quagga, christianity,
# Nearest to known: hay, appear, sisters, restrictive, consulted, nitroglycerin, krause, a,
# Nearest to there: it, choices, they, which, roll, buried, moderates, these,
# Nearest to they: it, he, not, there, censored, liberal, imbolc, ou,
# Nearest to new: depends, cutting, symplectic, signified, parl, pennsylvania, malagasy, bubble,
# Nearest to were: are, was, is, by, neutronic, and, compact, have,
# Nearest to two: four, three, five, one, six, seven, eight, neutronic,
# Average loss at step  32000 :  5.86339809763
# Average loss at step  34000 :  5.69057660413
# Average loss at step  36000 :  6.17423275548
# Average loss at step  38000 :  5.52611073494
# Average loss at step  40000 :  5.46461244774
# Nearest to nine: eight, seven, six, five, zero, four, three, neutronic,
# Nearest to was: is, were, has, by, had, aster, hemionus, neutronic,
# Nearest to UNK: sisters, modula, hymen, referendums, smells, palatalization, kiang, neutronic,
# Nearest to used: llc, erg, kiang, spool, tonal, imdb, reinventing, found,
# Nearest to s: and, his, zero, malagasy, the, hymen, kiang, or,
# Nearest to more: crowned, excalibur, electors, hfs, oxidant, intervene, iv, highlands,
# Nearest to has: had, was, is, have, in, s, paasikivi, widehat,
# Nearest to may: would, can, could, will, saxo, slope, prost, gw,
# Nearest to will: would, can, may, widehat, to, always, must, sokal,
# Nearest to use: bytecode, termination, misinterpretation, lives, amount, quagga, coast, nationalists,
# Nearest to known: hay, a, restrictive, appear, consulted, sisters, nitroglycerin, krause,
# Nearest to there: it, they, choices, he, these, which, that, modula,
# Nearest to they: it, he, not, there, we, you, swastika, who,
# Nearest to new: depends, cutting, apical, pennsylvania, symplectic, parl, bubble, everybody,
# Nearest to were: are, was, by, neutronic, is, have, be, and,
# Nearest to two: three, five, four, one, eight, six, seven, zero,
# Average loss at step  42000 :  5.32914524996
# Average loss at step  44000 :  5.03991268826
# Average loss at step  46000 :  5.2492436496
# Average loss at step  48000 :  5.35603876829
# Average loss at step  50000 :  5.25635976064
# Nearest to nine: eight, seven, six, zero, five, four, stadtbahn, gru,
# Nearest to was: is, has, were, had, by, became, flies, when,
# Nearest to UNK: sza, stadtbahn, sisters, six, modula, smells, hymen, arctocephalus,
# Nearest to used: erg, llc, kiang, stadtbahn, tonal, extremist, spool, found,
# Nearest to s: and, his, malagasy, szko, stadtbahn, hymen, zero, kiang,
# Nearest to more: crowned, excalibur, hfs, less, oxidant, electors, gru, intervene,
# Nearest to has: had, was, have, is, in, widehat, monsanto, eight,
# Nearest to may: would, can, could, will, saxo, cannot, must, gw,
# Nearest to will: would, can, may, to, must, widehat, always, could,
# Nearest to use: bytecode, termination, misinterpretation, amount, lives, nationalists, quagga, stadtbahn,
# Nearest to known: hay, restrictive, sisters, consulted, krause, appear, stadtbahn, such,
# Nearest to there: it, they, he, these, which, choices, modula, greenland,
# Nearest to they: he, it, there, not, we, you, swastika, who,
# Nearest to new: depends, cutting, apical, symplectic, stadtbahn, tons, everybody, parl,
# Nearest to were: are, was, by, have, neutronic, is, had, be,
# Nearest to two: five, three, four, six, one, seven, eight, stadtbahn,
# Average loss at step  52000 :  5.2592382369
# Average loss at step  54000 :  5.06106680584
# Average loss at step  56000 :  5.09180268455
# Average loss at step  58000 :  4.84828061056
# Average loss at step  60000 :  4.91089439464
# Nearest to nine: eight, seven, six, five, zero, four, three, stadtbahn,
# Nearest to was: is, were, has, had, by, when, became, lyman,
# Nearest to UNK: stadtbahn, sisters, sza, smells, modula, f, four, quagga,
# Nearest to used: llc, erg, kiang, found, stadtbahn, auratus, spool, reinventing,
# Nearest to s: and, his, malagasy, stadtbahn, zero, wilhelmshaven, hymen, szko,
# Nearest to more: less, crowned, hfs, excalibur, oxidant, most, electors, gru,
# Nearest to has: had, have, is, was, widehat, monsanto, in, ordinance,
# Nearest to may: can, would, could, will, saxo, cannot, should, might,
# Nearest to will: would, can, may, must, could, to, should, always,
# Nearest to use: bytecode, termination, amount, misinterpretation, quagga, stadtbahn, nationalists, lives,
# Nearest to known: hay, such, consulted, krause, restrictive, appear, described, considered,
# Nearest to there: it, they, he, these, which, choices, modula, buried,
# Nearest to they: he, there, it, we, not, you, swastika, who,
# Nearest to new: depends, apical, stadtbahn, cutting, everybody, tons, symplectic, pennsylvania,
# Nearest to were: are, was, have, had, is, neutronic, by, be,
# Nearest to two: five, four, three, six, one, seven, eight, stadtbahn,
# Average loss at step  62000 :  5.02412370527
# Average loss at step  64000 :  4.88853680384
# Average loss at step  66000 :  4.92228920817
# Average loss at step  68000 :  4.89809615815
# Average loss at step  70000 :  4.84543544543
# Nearest to nine: eight, seven, six, zero, five, four, three, stadtbahn,
# Nearest to was: is, has, were, had, by, when, lyman, flies,
# Nearest to UNK: stadtbahn, landesverband, sisters, hyi, sza, modula, smells, kiang,
# Nearest to used: llc, erg, kiang, hyi, found, stadtbahn, auratus, landsmannschaft,
# Nearest to s: his, malagasy, wilhelmshaven, stadtbahn, szko, zero, hymen, leon,
# Nearest to more: less, most, crowned, hfs, hyenas, excalibur, electors, oxidant,
# Nearest to has: had, was, have, is, landesverband, widehat, monsanto, landsmannschaft,
# Nearest to may: can, would, could, will, cannot, must, should, landesverband,
# Nearest to will: would, can, may, must, could, should, to, always,
# Nearest to use: bytecode, termination, amount, hyi, nationalists, misinterpretation, quagga, stadtbahn,
# Nearest to known: hay, such, described, consulted, krause, restrictive, used, begins,
# Nearest to there: it, they, he, which, these, modula, now, choices,
# Nearest to they: he, there, we, it, you, not, who, she,
# Nearest to new: dowleh, everybody, depends, signified, dark, apical, stadtbahn, parl,
# Nearest to were: are, was, have, had, by, be, neutronic, is,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Average loss at step  72000 :  4.87205607605
# Average loss at step  74000 :  4.82142886364
# Average loss at step  76000 :  4.78987906182
# Average loss at step  78000 :  4.6038829999
# Average loss at step  80000 :  4.7329367038
# Nearest to nine: eight, seven, six, five, four, zero, stadtbahn, hyi,
# Nearest to was: is, were, has, had, by, when, became, flies,
# Nearest to UNK: stadtbahn, landesverband, hyi, smells, modula, neutronic, sisters, widehat,
# Nearest to used: llc, mesocricetus, erg, found, kiang, considered, hyi, stadtbahn,
# Nearest to s: his, malagasy, stadtbahn, wilhelmshaven, szko, hymen, landesverband, zero,
# Nearest to more: less, most, crowned, hfs, hyenas, oxidant, mesocricetus, excalibur,
# Nearest to has: had, have, was, is, landesverband, widehat, monsanto, gru,
# Nearest to may: can, would, could, will, should, must, cannot, might,
# Nearest to will: would, can, may, could, must, should, to, cannot,
# Nearest to use: bytecode, amount, termination, hyi, nationalists, quagga, misinterpretation, stadtbahn,
# Nearest to known: such, described, hay, consulted, krause, used, fam, considered,
# Nearest to there: it, they, he, which, these, modula, now, stadtbahn,
# Nearest to they: there, he, we, it, you, not, who, she,
# Nearest to new: fam, dowleh, signified, everybody, depends, apical, exec, dark,
# Nearest to were: are, was, have, had, be, by, neutronic, been,
# Nearest to two: three, four, five, six, one, seven, eight, modula,
# Average loss at step  82000 :  4.74689513659
# Average loss at step  84000 :  4.72799686611
# Average loss at step  86000 :  4.71139037645
# Average loss at step  88000 :  4.65118186426
# Average loss at step  90000 :  4.61079802835
# Nearest to nine: eight, seven, six, five, zero, four, stadtbahn, hyi,
# Nearest to was: is, were, had, has, became, flies, gru, when,
# Nearest to UNK: stadtbahn, landesverband, modula, sisters, hyi, smells, three, fam,
# Nearest to used: found, mesocricetus, erg, llc, considered, kiang, stadtbahn, hyi,
# Nearest to s: his, szko, wilhelmshaven, malagasy, and, stadtbahn, hymen, landsmannschaft,
# Nearest to more: less, most, crowned, hfs, oxidant, hyenas, mesocricetus, gru,
# Nearest to has: had, have, was, is, landesverband, eilean, widehat, gru,
# Nearest to may: can, would, could, will, must, should, cannot, might,
# Nearest to will: would, can, may, could, must, should, to, cannot,
# Nearest to use: bytecode, amount, termination, hyi, misinterpretation, stadtbahn, quagga, nationalists,
# Nearest to known: such, described, used, hay, krause, consulted, riso, fam,
# Nearest to there: they, it, he, which, now, these, riso, modula,
# Nearest to they: he, there, we, you, it, she, not, who,
# Nearest to new: fam, everybody, dark, dowleh, exec, signified, apical, depends,
# Nearest to were: are, was, have, had, be, neutronic, by, been,
# Nearest to two: three, four, five, one, seven, six, modula, stadtbahn,
# Average loss at step  92000 :  4.29263922369
# Average loss at step  94000 :  4.50457209575
# Average loss at step  96000 :  4.43819756615
# Average loss at step  98000 :  4.53368825126
# Average loss at step  100000 :  4.57809920108
# Nearest to nine: eight, seven, six, four, five, zero, three, stadtbahn,
# Nearest to was: is, had, has, were, became, flies, when, gru,
# Nearest to UNK: stadtbahn, landesverband, hyi, sisters, modula, kiang, riso, smells,
# Nearest to used: found, mesocricetus, erg, llc, kiang, hyi, stadtbahn, known,
# Nearest to s: his, szko, isbn, and, malagasy, swift, stadtbahn, ebne,
# Nearest to more: less, most, crowned, hyenas, oxidant, hfs, mesocricetus, very,
# Nearest to has: had, have, was, is, landesverband, monsanto, gru, eilean,
# Nearest to may: can, would, could, will, should, must, cannot, might,
# Nearest to will: would, can, could, may, must, should, to, cannot,
# Nearest to use: bytecode, amount, termination, hyi, misinterpretation, quagga, stadtbahn, ebne,
# Nearest to known: such, described, used, hay, consulted, fam, riso, krause,
# Nearest to there: it, they, he, now, which, these, riso, modula,
# Nearest to they: he, there, we, you, it, she, not, who,
# Nearest to new: fam, dark, dowleh, apical, everybody, stadtbahn, exec, parl,
# Nearest to were: are, have, was, had, be, neutronic, is, by,
# Nearest to two: three, four, five, six, seven, one, eight, zero,

# %%
# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')

# %% [markdown]
# https://www.tensorflow.org/tutorials/word2vec
