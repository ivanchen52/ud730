# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.819057
# Nearest to zero: hermits, forceful, meaningful, olomouc, ecmascript, butch, gui, essenes,
# Nearest to see: kislev, franchising, gernsback, ayman, barnabas, interleague, diff, basso,
# Nearest to three: tableland, screwball, resumed, wd, intermarriages, tumor, busway, optical,
# Nearest to there: hodgson, manageable, neutralized, royston, crusaders, railroad, incorrect, pay,
# Nearest to six: earnings, richness, hydras, pirate, persuades, heysel, amylase, flaming,
# Nearest to was: borderline, ecu, geology, aqueducts, methods, seoul, glottalized, sine,
# Nearest to often: litre, vantage, condition, resented, rida, langue, her, penny,
# Nearest to this: mortgage, seraphim, mcgill, lovecraft, joule, terry, dst, voluntarily,
# Nearest to one: distinctions, bahia, gbu, arming, shir, majdanek, sgi, james,
# Nearest to were: anacreon, manifestos, hike, aquaria, latinate, folded, mundo, snopes,
# Nearest to years: sociology, sasl, smartest, corsica, fabrics, darrell, cbd, withers,
# Nearest to UNK: silverberg, preserving, replica, stanislavski, virgins, kagoshima, tractable, procol,
# Nearest to d: impacted, manipulating, animistic, sly, employees, vague, tubas, anschluss,
# Nearest to but: psycho, presbyterians, henrik, peso, barrie, tabulation, tomorrowland, trigonometric,
# Nearest to between: scolded, edifice, rossetti, foibles, flywheels, coloured, exp, salad,
# Nearest to a: chmielnicki, dominicans, jelly, dnia, icd, bosworth, mycenaean, seq,
# Average loss at step 2000: 4.365998
# Average loss at step 4000: 3.866572
# Average loss at step 6000: 3.788164
# Average loss at step 8000: 3.688342
# Average loss at step 10000: 3.615398
# Nearest to zero: nine, seven, six, five, eight, three, four, two,
# Nearest to see: aconcagua, mattel, joule, basso, accomplished, dread, scales, torch,
# Nearest to three: four, seven, six, eight, five, two, nine, zero,
# Nearest to there: it, they, hodgson, he, cholesterol, citrus, generally, often,
# Nearest to six: eight, seven, nine, three, five, four, zero, two,
# Nearest to was: is, has, had, were, be, by, joining, been,
# Nearest to often: ouadda, not, there, it, cryptographer, usually, sometimes, mullis,
# Nearest to this: it, which, the, that, cay, usmc, mortgage, a,
# Nearest to one: two, seven, three, six, four, eight, five, relativistic,
# Nearest to were: are, was, had, have, subcommittee, be, fibrosis, succumbing,
# Nearest to years: rule, kabaddi, aidan, births, magazines, chordal, corsica, cbd,
# Nearest to UNK: writer, kagoshima, televisions, freebase, f, tomcat, theogony, farmed,
# Nearest to d: manipulating, impacted, tubas, metroid, na, yaw, vincenzo, animistic,
# Nearest to but: and, androids, disciplined, refinement, henrik, unsatisfied, ugo, moog,
# Nearest to between: fundamentalists, exp, arundel, rabbit, glace, in, evicted, scolded,
# Nearest to a: the, chmielnicki, editorship, retreated, seq, sailboat, andromache, this,
# Average loss at step 12000: 3.597417
# Average loss at step 14000: 3.574055
# Average loss at step 16000: 3.408556
# Average loss at step 18000: 3.461705
# Average loss at step 20000: 3.540615
# Nearest to zero: six, five, seven, four, nine, three, eight, two,
# Nearest to see: aconcagua, swine, mattel, joule, torch, scales, accomplished, gernsback,
# Nearest to three: four, seven, five, two, six, eight, zero, nine,
# Nearest to there: they, it, he, which, still, generally, often, alphorn,
# Nearest to six: seven, eight, four, five, nine, three, zero, two,
# Nearest to was: is, were, has, had, became, be, alexis, ecu,
# Nearest to often: usually, sometimes, commonly, there, it, ouadda, still, also,
# Nearest to this: which, it, that, cay, the, zoning, packages, a,
# Nearest to one: two, three, four, seven, eight, five, six, nine,
# Nearest to were: are, was, had, have, be, been, fibrosis, pci,
# Nearest to years: days, times, rule, values, aidan, tenzin, allis, stepney,
# Nearest to UNK: h, explosive, nash, mmc, quod, explore, smoothness, mor,
# Nearest to d: b, manipulating, vincenzo, na, yaw, summarize, impacted, instantaneously,
# Nearest to but: however, and, only, does, although, that, bouldering, which,
# Nearest to between: from, with, in, rabbit, over, arundel, evicted, exp,
# Nearest to a: the, quite, no, this, retreated, editorship, any, another,
# Average loss at step 22000: 3.501692
# Average loss at step 24000: 3.487820
# Average loss at step 26000: 3.480907
# Average loss at step 28000: 3.477442
# Average loss at step 30000: 3.505175
# Nearest to zero: five, eight, six, nine, four, seven, three, two,
# Nearest to see: aconcagua, torch, mattel, swine, are, gernsback, webern, scales,
# Nearest to three: four, five, seven, eight, six, two, nine, zero,
# Nearest to there: they, it, he, now, still, usually, alphorn, often,
# Nearest to six: eight, four, nine, five, seven, three, zero, two,
# Nearest to was: is, were, has, had, became, been, be, after,
# Nearest to often: usually, sometimes, commonly, generally, still, also, there, widely,
# Nearest to this: which, it, cay, zoning, there, any, that, alexandrian,
# Nearest to one: two, seven, four, three, six, five, eight, nine,
# Nearest to were: are, was, have, had, been, be, is, by,
# Nearest to years: days, times, year, allis, schroeder, rule, catiline, tenzin,
# Nearest to UNK: lilith, zionist, subgroups, applauded, distribution, transclusion, jean, eras,
# Nearest to d: b, manipulating, na, vincenzo, instantaneously, galt, jammu, afghans,
# Nearest to but: however, and, although, though, which, bouldering, that, is,
# Nearest to between: with, rabbit, in, exp, evicted, over, coloured, glace,
# Nearest to a: tica, andromache, the, no, any, burgundian, telescopes, quite,
# Average loss at step 32000: 3.499818
# Average loss at step 34000: 3.499942
# Average loss at step 36000: 3.459348
# Average loss at step 38000: 3.294609
# Average loss at step 40000: 3.432788
# Nearest to zero: five, seven, eight, nine, six, three, four, two,
# Nearest to see: aconcagua, torch, taunus, swine, webern, includes, mattel, intervene,
# Nearest to three: four, seven, six, five, two, eight, nine, zero,
# Nearest to there: it, they, he, now, still, usually, alphorn, which,
# Nearest to six: four, eight, seven, five, three, nine, zero, two,
# Nearest to was: is, became, had, has, were, been, initialized, be,
# Nearest to often: usually, sometimes, generally, commonly, still, widely, also, there,
# Nearest to this: which, that, it, the, another, any, what, cay,
# Nearest to one: seven, eight, six, two, five, four, three, nine,
# Nearest to were: are, have, was, had, been, be, redistribution, ghent,
# Nearest to years: days, times, year, allis, values, months, schroeder, rooting,
# Nearest to UNK: d, buses, b, amer, quod, atheist, la, floating,
# Nearest to d: b, manipulating, UNK, jammu, e, na, sensual, dynamic,
# Nearest to but: however, though, although, and, when, it, are, where,
# Nearest to between: with, rabbit, over, exp, evicted, arundel, coloured, intifada,
# Nearest to a: the, another, auden, quite, excerpts, tica, adware, any,
# Average loss at step 42000: 3.430847
# Average loss at step 44000: 3.452815
# Average loss at step 46000: 3.453930
# Average loss at step 48000: 3.353799
# Average loss at step 50000: 3.381897
# Nearest to zero: eight, five, nine, seven, six, four, three, two,
# Nearest to see: aconcagua, includes, inflexible, list, webern, eclipsing, include, references,
# Nearest to three: seven, four, six, eight, nine, two, five, zero,
# Nearest to there: they, it, he, now, still, often, usually, alphorn,
# Nearest to six: eight, seven, four, nine, three, five, zero, two,
# Nearest to was: is, became, were, has, had, be, are, alexis,
# Nearest to often: usually, sometimes, generally, commonly, widely, still, also, there,
# Nearest to this: which, it, the, cay, zoning, that, he, some,
# Nearest to one: two, four, seven, six, eight, three, five, nine,
# Nearest to were: are, have, was, be, had, redistribution, pci, these,
# Nearest to years: days, times, months, year, allis, decades, values, modeled,
# Nearest to UNK: la, de, babies, rds, et, vestments, washtenaw, zionist,
# Nearest to d: b, manipulating, e, na, jammu, dynamic, summarize, galt,
# Nearest to but: however, although, though, and, when, until, while, which,
# Nearest to between: with, rabbit, over, arundel, within, evicted, among, in,
# Nearest to a: another, the, any, retreated, no, editorship, sars, quite,
# Average loss at step 52000: 3.438271
# Average loss at step 54000: 3.430078
# Average loss at step 56000: 3.434847
# Average loss at step 58000: 3.394274
# Average loss at step 60000: 3.393685
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to see: includes, but, include, list, can, drummer, references, aconcagua,
# Nearest to three: five, four, eight, six, two, seven, nine, zero,
# Nearest to there: they, it, still, now, he, usually, often, we,
# Nearest to six: eight, four, five, nine, seven, three, two, zero,
# Nearest to was: is, had, became, were, has, be, when, initialized,
# Nearest to often: usually, sometimes, commonly, generally, still, also, widely, now,
# Nearest to this: which, it, the, some, that, what, there, any,
# Nearest to one: two, eight, four, seven, six, five, three, nine,
# Nearest to were: are, was, have, had, including, although, those, be,
# Nearest to years: days, times, months, year, decades, allis, weeks, modeled,
# Nearest to UNK: vestments, zangger, gameplay, overload, rebellions, unconcerned, e, wagon,
# Nearest to d: b, manipulating, jammu, c, na, e, sensual, h,
# Nearest to but: however, although, and, though, see, which, when, than,
# Nearest to between: with, over, within, in, coloured, among, nominal, across,
# Nearest to a: another, the, any, auden, sars, tica, listened, depositing,
# Average loss at step 62000: 3.243469
# Average loss at step 64000: 3.255651
# Average loss at step 66000: 3.400157
# Average loss at step 68000: 3.396384
# Average loss at step 70000: 3.357018
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to see: list, include, includes, drummer, references, but, inflexible, trigonometry,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to there: they, it, still, we, now, he, usually, she,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to was: is, had, were, has, been, be, became, originally,
# Nearest to often: usually, sometimes, generally, commonly, still, now, widely, also,
# Nearest to this: which, it, the, some, that, another, there, what,
# Nearest to one: two, seven, six, four, eight, five, nine, three,
# Nearest to were: are, was, have, had, be, pci, including, although,
# Nearest to years: days, months, times, year, decades, hours, centuries, modeled,
# Nearest to UNK: intra, tiki, astronomical, ladislaus, vestments, rees, ash, technocrats,
# Nearest to d: manipulating, b, jammu, humberto, e, urdu, poke, sensual,
# Nearest to but: however, although, which, though, while, and, that, actually,
# Nearest to between: with, coloured, within, among, scolded, intifada, rabbit, over,
# Nearest to a: another, the, sars, any, tica, quite, auden, this,
# Average loss at step 72000: 3.379026
# Average loss at step 74000: 3.344377
# Average loss at step 76000: 3.322787
# Average loss at step 78000: 3.349269
# Average loss at step 80000: 3.379032
# Nearest to zero: seven, five, eight, six, four, nine, three, two,
# Nearest to see: list, but, according, include, references, includes, inflexible, allow,
# Nearest to three: six, four, five, seven, eight, two, nine, zero,
# Nearest to there: they, it, he, she, still, we, usually, often,
# Nearest to six: seven, five, four, eight, three, nine, zero, two,
# Nearest to was: is, had, became, were, has, been, arginine, be,
# Nearest to often: usually, sometimes, generally, commonly, still, typically, now, frequently,
# Nearest to this: which, it, the, another, what, that, itself, hoped,
# Nearest to one: six, seven, two, three, four, eight, five, nine,
# Nearest to were: are, had, have, was, pci, those, be, these,
# Nearest to years: days, months, times, decades, year, weeks, hours, minutes,
# Nearest to UNK: haze, kimball, davis, mrna, avatars, smith, lingered, coach,
# Nearest to d: b, manipulating, jammu, c, e, humberto, p, integrins,
# Nearest to but: however, although, while, and, though, which, see, they,
# Nearest to between: within, among, over, from, with, in, rabbit, coloured,
# Nearest to a: another, the, tica, retreated, adware, rearing, andromache, statism,
# Average loss at step 82000: 3.406248
# Average loss at step 84000: 3.407171
# Average loss at step 86000: 3.389734
# Average loss at step 88000: 3.354659
# Average loss at step 90000: 3.364152
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to see: list, references, includes, include, but, sravaka, pdf, aconcagua,
# Nearest to three: five, four, two, eight, six, seven, zero, nine,
# Nearest to there: they, it, still, he, she, we, now, alphorn,
# Nearest to six: seven, five, four, eight, nine, three, two, zero,
# Nearest to was: is, had, became, were, has, been, be, epiphany,
# Nearest to often: usually, sometimes, generally, commonly, still, now, actually, frequently,
# Nearest to this: it, which, the, another, any, some, itself, what,
# Nearest to one: two, seven, four, six, eight, five, three, nine,
# Nearest to were: are, was, had, have, while, pci, although, anita,
# Nearest to years: days, months, decades, year, times, hours, weeks, minutes,
# Nearest to UNK: lica, footwear, hillsborough, woodward, dora, bali, musk, canonical,
# Nearest to d: b, manipulating, jammu, integrins, edirne, terminator, t, fractures,
# Nearest to but: however, although, and, while, though, which, that, directv,
# Nearest to between: within, with, through, coloured, among, across, over, in,
# Nearest to a: another, any, the, sars, every, tica, auden, rearing,
# Average loss at step 92000: 3.398475
# Average loss at step 94000: 3.254699
# Average loss at step 96000: 3.359853
# Average loss at step 98000: 3.241778
# Average loss at step 100000: 3.358189
# Nearest to zero: four, five, six, eight, seven, nine, three, two,
# Nearest to see: includes, references, list, bulletins, pdf, include, sravaka, can,
# Nearest to three: four, five, seven, two, six, eight, nine, zero,
# Nearest to there: they, it, still, we, he, she, now, often,
# Nearest to six: seven, four, five, eight, nine, zero, three, two,
# Nearest to was: is, became, had, were, has, been, although, when,
# Nearest to often: usually, sometimes, generally, commonly, still, typically, now, actually,
# Nearest to this: it, which, another, itself, he, she, the, what,
# Nearest to one: two, four, seven, six, eight, five, three, nine,
# Nearest to were: are, was, have, these, those, had, although, anita,
# Nearest to years: days, year, decades, months, hours, times, weeks, minutes,
# Nearest to UNK: unconcerned, unqualified, spills, dora, josip, intra, vestments, demolished,
# Nearest to d: b, manipulating, c, ser, jammu, afghans, mutated, gions,
# Nearest to but: however, although, and, though, while, which, schaeffer, actually,
# Nearest to between: over, within, coloured, among, with, through, intifada, arundel,
# Nearest to a: another, any, sars, the, hail, tica, rearing, cutters,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in range(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  263.91784668
# Nearest to they: devon, frideric, heracles, beltaine, babbage, surprise, calm, extremely,
# Nearest to six: flirted, helsing, suites, torah, poee, tomasz, tolls, pew,
# Nearest to was: gubernatorial, sheldon, angolan, flamsteed, slide, arresting, nous, shaivism,
# Nearest to see: softening, apologists, sabra, defraud, fucking, epistle, bidirectional, gorillaz,
# Nearest to often: wondered, eckert, rahman, crassus, multiplied, rapier, bentheim, fantastic,
# Nearest to into: exposed, sitcoms, sheath, adhering, fair, synonyms, hsbc, lorry,
# Nearest to it: eva, ratification, investigative, pollock, katha, recourse, ducati, few,
# Nearest to seven: gregor, tyrol, motorsport, xry, licklider, anointing, drunkenness, voyaging,
# Nearest to there: gdynia, effort, signage, debts, smalley, kirlian, disgraceful, rationally,
# Nearest to united: jaffe, zaragoza, ios, mismatch, competencies, region, hamilton, hybrid,
# Nearest to between: universitet, ecuadorian, schemes, saudis, broadcasts, analytics, html, migrants,
# Nearest to five: roundabout, sdk, examines, syntactic, duesberg, rochester, motherland, danio,
# Nearest to will: relative, heathen, toxin, vapors, thereto, pickups, tuskegee, invader,
# Nearest to of: intervened, snacks, toledo, smirnov, hussites, guess, withhold, hurst,
# Nearest to while: excerpted, himmler, agricultural, druyan, quackery, abort, snows, unwavering,
# Nearest to first: montag, apollodorus, deduce, erhard, hurriedly, platonic, basal, crystallizes,
# Average loss at step  2000 :  115.267139273
# Average loss at step  4000 :  52.3126692896
# Average loss at step  6000 :  33.060954968
# Average loss at step  8000 :  23.2561338707
# Average loss at step  10000 :  16.9731890121
# Nearest to they: circumference, it, hyperbolic, calm, hymen, believed, supper, organizations,
# Nearest to six: five, nine, zero, believed, eight, kim, netbios, flies,
# Nearest to was: is, toei, were, catalytic, in, circumference, s, and,
# Nearest to see: olympian, familiar, dismissed, edges, seven, channel, say, dong,
# Nearest to often: rahman, difficult, circular, cerf, fantastic, student, sons, mtu,
# Nearest to into: toei, exposed, fair, offered, wagoner, was, olympian, viola,
# Nearest to it: he, compression, they, also, recourse, which, few, rance,
# Nearest to seven: zero, nine, four, sousa, netbios, fc, mtu, regiments,
# Nearest to there: born, effort, banjo, inhibition, dost, omega, dallas, origin,
# Nearest to united: caucasus, kant, upload, hotel, ships, demographics, scandinavian, region,
# Nearest to between: ecuadorian, schemes, broadcasts, html, earn, projectors, define, most,
# Nearest to five: zero, nine, dione, six, fc, one, three, eight,
# Nearest to will: relative, heathen, loci, bioko, programmes, trivial, move, aggression,
# Nearest to of: and, in, for, on, from, zero, nine, berman,
# Nearest to while: et, contention, circumference, hotspot, or, pled, brother, elevations,
# Nearest to first: signed, structured, pegasus, singles, worth, dsl, multidimensional, netbios,
# Average loss at step  12000 :  13.8110081549
# Average loss at step  14000 :  11.627790718
# Average loss at step  16000 :  10.260955416
# Average loss at step  18000 :  8.77280736637
# Average loss at step  20000 :  7.99521014619
# Nearest to they: it, circumference, he, who, hyperbolic, offshore, writeups, there,
# Nearest to six: five, nine, zero, eight, seven, three, two, one,
# Nearest to was: is, were, has, had, by, toei, s, circumference,
# Nearest to see: olympian, leith, familiar, dismissed, channel, edges, epistle, electroplating,
# Nearest to often: difficult, fantastic, circular, cerf, sons, cues, suspicious, there,
# Nearest to into: toei, in, fair, exposed, synonyms, by, was, to,
# Nearest to it: he, this, they, also, compression, which, eva, sld,
# Nearest to seven: nine, zero, four, eight, five, widehat, six, smells,
# Nearest to there: born, it, they, removes, inhibition, banjo, often, one,
# Nearest to united: zaragoza, caucasus, patience, upload, latest, kant, environmentalism, unanimously,
# Nearest to between: in, and, broadcasts, schemes, guatemala, projectors, with, taxes,
# Nearest to five: zero, nine, eight, six, four, three, one, two,
# Nearest to will: relative, loci, heathen, bioko, tyrant, trivial, cheques, discharge,
# Nearest to of: and, in, for, from, nine, s, widehat, with,
# Nearest to while: or, and, et, circumference, contention, elevations, widehat, painful,
# Nearest to first: erlang, deduce, signed, structured, shadowy, in, volatile, through,
# Average loss at step  22000 :  7.43805831003
# Average loss at step  24000 :  6.85149326426
# Average loss at step  26000 :  6.3684019767
# Average loss at step  28000 :  6.25924761367
# Average loss at step  30000 :  6.20365403843
# Nearest to they: it, he, circumference, who, there, you, also, not,
# Nearest to six: five, eight, nine, four, seven, zero, three, two,
# Nearest to was: is, were, has, had, by, toei, are, circumference,
# Nearest to see: sabra, olympian, leith, dismissed, familiar, electroplating, edges, seven,
# Nearest to often: there, difficult, taunus, dop, quagga, cerf, it, circular,
# Nearest to into: toei, from, fair, in, through, synonyms, viola, with,
# Nearest to it: he, this, they, which, also, taunus, eva, compression,
# Nearest to seven: nine, four, eight, five, six, zero, widehat, three,
# Nearest to there: it, waterman, they, one, often, born, this, removes,
# Nearest to united: zaragoza, caucasus, daigo, quagga, latest, neutronic, upload, beefheart,
# Nearest to between: in, with, schemes, projectors, broadcasts, guatemala, as, taxes,
# Nearest to five: eight, six, four, nine, three, seven, zero, two,
# Nearest to will: relative, can, loci, could, trivial, tyrant, should, bioko,
# Nearest to of: in, for, and, from, neutronic, at, surveyed, widehat,
# Nearest to while: or, neutronic, excerpted, pentagons, circumference, contention, painful, and,
# Nearest to first: montag, erlang, deduce, kiang, apollodorus, signed, shadowy, structured,
# Average loss at step  32000 :  5.89295087886
# Average loss at step  34000 :  5.71532259536
# Average loss at step  36000 :  6.09607951313
# Average loss at step  38000 :  5.50453617966
# Average loss at step  40000 :  5.49166591704
# Nearest to they: it, he, you, there, who, circumference, we, not,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to was: is, were, has, had, by, toei, are, mvs,
# Nearest to see: sabra, olympian, leith, arctocephalus, dismissed, electroplating, generalization, epistle,
# Nearest to often: there, they, difficult, taunus, it, dop, fantastic, cerf,
# Nearest to into: from, through, with, by, toei, in, fair, viola,
# Nearest to it: he, this, they, which, also, there, modula, taunus,
# Nearest to seven: eight, six, nine, four, five, zero, three, two,
# Nearest to there: it, they, waterman, who, now, often, which, removes,
# Nearest to united: zaragoza, modula, caucasus, ios, latest, daigo, neutronic, quagga,
# Nearest to between: in, with, sideband, projectors, schemes, broadcasts, bokassa, taxes,
# Nearest to five: four, three, six, eight, seven, two, zero, nine,
# Nearest to will: can, to, could, should, relative, would, loci, trivial,
# Nearest to of: and, in, for, from, bezier, neutronic, arctocephalus, modula,
# Nearest to while: or, and, neutronic, circumference, pentagons, contention, domo, widehat,
# Nearest to first: montag, erlang, deduce, kiang, through, shadowy, signed, antiquark,
# Average loss at step  42000 :  5.36110538614
# Average loss at step  44000 :  5.01858527386
# Average loss at step  46000 :  5.23297888863
# Average loss at step  48000 :  5.36380136421
# Average loss at step  50000 :  5.21541948366
# Nearest to they: he, it, you, there, we, who, circumference, not,
# Nearest to six: seven, five, eight, four, three, nine, zero, stadtbahn,
# Nearest to was: is, were, has, had, by, toei, be, been,
# Nearest to see: olympian, sabra, arctocephalus, and, leith, generalization, electroplating, modula,
# Nearest to often: there, also, generally, taunus, now, difficult, it, they,
# Nearest to into: from, through, stadtbahn, in, toei, by, viola, with,
# Nearest to it: he, this, they, there, which, modula, she, taunus,
# Nearest to seven: eight, six, five, four, nine, three, zero, stadtbahn,
# Nearest to there: it, they, who, now, waterman, often, he, still,
# Nearest to united: zaragoza, caucasus, modula, ios, latest, stadtbahn, daigo, emf,
# Nearest to between: with, in, and, sideband, projectors, universitet, schemes, are,
# Nearest to five: four, six, three, seven, eight, two, zero, nine,
# Nearest to will: can, would, could, should, to, may, trivial, relative,
# Nearest to of: in, stadtbahn, nine, and, for, neutronic, arctocephalus, modula,
# Nearest to while: or, and, neutronic, szko, circumference, four, pentagons, excerpted,
# Nearest to first: montag, erlang, in, clp, modula, through, antiquark, custis,
# Average loss at step  52000 :  5.23530060279
# Average loss at step  54000 :  5.0402264545
# Average loss at step  56000 :  5.11501817429
# Average loss at step  58000 :  4.84113112259
# Average loss at step  60000 :  4.93335797608
# Nearest to they: he, there, it, you, we, who, not, circumference,
# Nearest to six: seven, five, eight, four, three, nine, zero, two,
# Nearest to was: is, were, has, had, by, when, toei, be,
# Nearest to see: olympian, sabra, arctocephalus, modula, generalization, leith, stadtbahn, occupy,
# Nearest to often: there, generally, sometimes, also, it, difficult, now, typically,
# Nearest to into: through, from, by, stadtbahn, viola, within, with, toei,
# Nearest to it: he, this, there, they, which, she, modula, also,
# Nearest to seven: eight, six, five, four, three, nine, zero, two,
# Nearest to there: it, they, galatea, who, he, which, now, still,
# Nearest to united: zaragoza, caucasus, modula, latest, ios, stadtbahn, daigo, rias,
# Nearest to between: with, in, hwv, sideband, universitet, projectors, dusk, korchnoi,
# Nearest to five: six, seven, four, three, eight, two, nine, zero,
# Nearest to will: can, would, could, should, may, to, must, trivial,
# Nearest to of: stadtbahn, in, nine, modula, olympian, and, neutronic, quagga,
# Nearest to while: or, and, neutronic, where, szko, widehat, circumference, after,
# Nearest to first: montag, attach, clp, erlang, modula, custis, refugees, widehat,
# Average loss at step  62000 :  5.01575571609
# Average loss at step  64000 :  4.86964694512
# Average loss at step  66000 :  4.89819598544
# Average loss at step  68000 :  4.94344810677
# Average loss at step  70000 :  4.83699314141
# Nearest to they: he, there, you, we, it, who, not, circumference,
# Nearest to six: seven, eight, five, four, nine, three, zero, hyi,
# Nearest to was: is, has, were, had, by, became, toei, when,
# Nearest to see: olympian, landesverband, arctocephalus, hyi, modula, leith, sabra, logically,
# Nearest to often: generally, there, landesverband, sometimes, typically, also, now, usually,
# Nearest to into: through, from, in, stadtbahn, by, viola, with, within,
# Nearest to it: he, this, there, she, which, they, modula, landesverband,
# Nearest to seven: eight, six, five, four, nine, three, zero, hyi,
# Nearest to there: it, they, he, galatea, still, who, now, often,
# Nearest to united: zaragoza, caucasus, modula, latest, ios, stadtbahn, daigo, emf,
# Nearest to between: with, in, hwv, hopwood, sideband, projectors, dusk, universitet,
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to will: can, would, could, should, may, to, must, did,
# Nearest to of: landesverband, stadtbahn, in, for, neutronic, nine, eight, at,
# Nearest to while: or, and, landesverband, neutronic, where, but, szko, after,
# Nearest to first: montag, attach, hyi, modula, clp, widehat, custis, erlang,
# Average loss at step  72000 :  4.87129348719
# Average loss at step  74000 :  4.82612587094
# Average loss at step  76000 :  4.79900169802
# Average loss at step  78000 :  4.60471555102
# Average loss at step  80000 :  4.72307125306
# Nearest to they: there, he, we, you, it, who, not, circumference,
# Nearest to six: seven, five, four, eight, three, nine, zero, hyi,
# Nearest to was: is, were, has, had, by, became, when, toei,
# Nearest to see: but, olympian, logically, landesverband, generalization, twitch, arctocephalus, hyi,
# Nearest to often: generally, sometimes, there, typically, landesverband, also, now, usually,
# Nearest to into: through, from, stadtbahn, within, viola, toei, on, landesverband,
# Nearest to it: he, this, there, she, which, they, modula, gastroenterology,
# Nearest to seven: six, five, eight, four, nine, zero, three, hyi,
# Nearest to there: they, it, he, now, still, galatea, often, who,
# Nearest to united: zaragoza, caucasus, modula, latest, stadtbahn, ios, emf, daigo,
# Nearest to between: with, in, hwv, hopwood, sideband, universitet, projectors, dusk,
# Nearest to five: four, six, seven, three, eight, zero, nine, hyi,
# Nearest to will: can, would, could, should, may, to, must, did,
# Nearest to of: landesverband, stadtbahn, in, nine, and, neutronic, modula, fibonacci,
# Nearest to while: or, and, landesverband, but, neutronic, where, when, four,
# Nearest to first: montag, attach, clp, modula, hyi, custis, preamble, same,
# Average loss at step  82000 :  4.74939642906
# Average loss at step  84000 :  4.72909537423
# Average loss at step  86000 :  4.70886490339
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-6b9445399dd6> in <module>()
#      15     # We perform one update step by evaluating the optimizer op (including it
#      16     # in the list of returned values for session.run()
# ---> 17     _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
#      18     average_loss += loss_val
#      19
#
# /Users/ivanchen/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/ivanchen/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /Users/ivanchen/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/ivanchen/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /Users/ivanchen/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')

# %% [markdown]
# https://www.tensorflow.org/tutorials/word2vec
